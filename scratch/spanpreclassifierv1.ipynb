# %%
from coggle.span_detection import span_splitter, run_nlp
from coggle.span_classifier_v1 import classify_spans

test_query =  "move photos and videos to archive"
run_nlp(test_query)
for token in run_nlp(test_query):
    print(token.text, token.pos_, token.dep_)
print(span_splitter(run_nlp(test_query)))
print(classify_spans(span_splitter(run_nlp(test_query))))
# Out:
# move VERB ROOT
# photos NOUN dobj
# and CCONJ cc
# videos NOUN conj
# to PART aux
# archive VERB xcomp
# [[photos, and, videos], [to, archive]]
# [ClassifiedSpan(role='target', text='photos and videos'), ClassifiedSpan(role='target', text='to archive')]
