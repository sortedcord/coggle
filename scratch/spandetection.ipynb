# %% [markdown]
# ## Span Detection using spaCY en_core_web_sm

# %%
from coggle.span_detection import span_splitter, run_nlp 

test_query = "rename all logs older than 30 days to start with something else"

run_nlp(test_query)
for token in run_nlp(test_query):
    print(token.text, token.pos_, token.dep_)
print(span_splitter(run_nlp(test_query)))
# Out:
# rename ADJ amod
# all DET det
# logs NOUN ROOT
# older ADJ amod
# than ADP prep
# 30 NUM nummod
# days NOUN pobj
# to PART aux
# start VERB advcl
# with ADP prep
# something PRON pobj
# else ADV advmod
# [['all', 'logs'], ['older', 'than', '30', 'days', 'to'], ['start', 'with', 'something', 'else']]
