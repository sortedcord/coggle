# %% [markdown]
# ## Span Detection using spaCY en_core_web_sm

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Move all images and videos from mydir to anotherdir")

# %%
doc = nlp("copy all files starting with a into mydir")

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# copy VERB ROOT
# all DET det
# files NOUN dobj
# starting VERB acl
# with ADP prep
# a PRON pobj
# into ADP prep
# mydir NOUN pobj

# %%
from spandetection import span_splitter

span_splitter(doc)
# Out:
# [[all, files, starting], [with, a], [into, mydir]]
