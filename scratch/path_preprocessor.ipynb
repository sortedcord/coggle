# %%
from coggle.path_preprocessor import preprocess_paths

# Here if runner is actually a file in CWD then it will be marked as a path
res = preprocess_paths("set runner as executable and move it to /usr/local/bin")
print(res)
# Out:
# ('set myfilepath1 as executable and move it to mydirpath0', {'mydirpath0': PathContext(original='/usr/local/bin', placeholder='mydirpath0', is_file=False, mime=None, existed=True), 'myfilepath1': PathContext(original='runner', placeholder='myfilepath1', is_file=True, mime=None, existed=True)})
